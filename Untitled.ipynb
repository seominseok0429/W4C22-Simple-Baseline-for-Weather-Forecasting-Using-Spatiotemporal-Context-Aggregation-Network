# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = './ori_1.npy'
path1 = './flip_1.npy'
path2 = './ens_1.npy'
path3 = './y_1.npy'
path4 = './y_0.21.npy'

# %%
data =np.load(path)
data1 =np.load(path1)
data2 =np.load(path2)
data3 =np.load(path3)
data4 =np.load(path4)

# %%
data_ = data[14,0,:,:,:]
data1_ = data1[14,0,:,:,:]
data2_ = data2[14,0,:,:,:]
data3_ = data3[14,0,:,:,:]
data4_ = data4[14,0,:,:,:]

# %%
plt.imshow(data3_[4,:,:]+data4_[4,:,:])
plt.imsave('gt.png', data3_[4,:,:]+data4_[4,:,:])

# %%
plt.imshow(data2_[4,:,:])
plt.imsave('ap.png', data2_[4,:,:])

# %%
plt.imsave('gt.png', data3_[4,:,:]+data4_[4,:,:])

# %%
plt.imshow(data_[22,:,:])
plt.imsave('s.png', data_[22,:,:],)

# %%
plt.imshow(data_[22,:,:])

# %%
aa = data2_[4,:,:]

# %%
aa[aa>0.3]=1
aa[aa!=1] =0

# %%
plt.imshow(aa)
plt.imsave('pred.png', aa)

# %%
xx_0.npy

# %%
patha = './xx_1.npy'
dataa = np.load(patha)
dataa.shape
# Out:
# (16, 4, 252, 252)

# %%
plt.imshow(dataa[4,0,:,:])
plt.imsave('op1.png',dataa[4,0,:,:] )
plt.imsave('op2.png',dataa[4,3,:,:] )

# %%
dataa.shpae
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [351], line 1
# ----> 1 dataa.shpae
#
# AttributeError: 'numpy.ndarray' object has no attribute 'shpae'
